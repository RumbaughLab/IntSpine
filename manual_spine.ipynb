# %%
# %matplotlib ipympl
# import manual_spine
import manual_auto_seed
# Z:\2026 - E19 Project collab spine and dendrites\Respan\202607013_makingCAREmodel_deconvolution+GaussianFilter\nocare_MS\TEST1\New folder
# import importlib
# importlib.reload(manual_auto_seed)
# Out:
# VBox(children=(HBox(children=(VBox(children=(Text(value='', description='Input Folder:', layout=Layout(width='…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
